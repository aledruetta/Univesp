# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
UG = nx.MultiDiGraph()
E = [(1, 2), (2, 3), (3, 1), (1, 3), (3, 3)]
N = [1, 2, 3]
UG.add_nodes_from(N)
UG.add_edges_from(E)
nx.draw_networkx(UG)
